# %% [markdown]
# # Differences between formal and functional tags (Nestle1904GBI)

# %% [markdown]
# ## Table of content <a class="anchor" id="TOC">
# * [1: introduction](#first-bullet)
#     * [1.1 Why is this relevant?](#bullet1_1)
#     * [1.2 Translating into Text-Fabric queries](#bullet1_2)
#     * [1.3 Notes](bullet1_3")
# * [2: Load Text-Fabric app and data](#second-bullet)
# * [3: Performing the queries](#third-bullet)
#     * [3.1 Table with differences between formal and functional tag](#bullet3_1)
#     * [3.2 Frequency of changes between form and function](#bullet3_2)
#     * [3.3 Diagram with differences between formal and functional tag](#bullet3_3)

# %% [markdown]
# ## Introduction <a class="anchor" id="first-bullet"></a>
#
# In this example a list will be created of instances where the formal and functional tags differ. Both the [formal tag](https://github.com/tonyjurg/Nestle1904GBI/blob/main/docs/features/formaltag.md) and [functional tag](https://github.com/tonyjurg/Nestle1904GBI/blob/main/docs/features/functionaltag.md) are according to Sandborg-Petersen morphology.
#
# ## 1.1 Why is this relevant? <a class="anchor" id="bullet1_1"></a>
#
# A basic concept in linguistics and biblical interpretation is the fundamental idea that syntax (the relationships between words) determines meaning more than morphology alone. Hence, how words are used in context is most determinative than their individual meaning. The view is that there are multiple "layers" of language.[^1] There are situations where the form of a word does not match what we expect for its function . Sometimes there are exceptions for poetic reasons, emphasis, or idiom. The overall flow and logic of the passage determine function, not rigid rules of form.
#
# ## 1.2 Translating it into Text-Fabric queries <a class="anchor" id="bullet1_2"></a>
#
# This reletively easly done in this dataset due to the readily availability of the two relevant features: [formal tag](https://github.com/tonyjurg/Nestle1904GBI/blob/main/docs/features/formaltag.md) and [functional tag](https://github.com/tonyjurg/Nestle1904GBI/blob/main/docs/features/functionaltag.md). The main logic is just to compare the values of these features with each other and select any case where a difference is found.
#
# ## 1.3 Notes <a class="anchor" id="bullet1_3"></a>
#
# [^1]: Porter, S. E. in S. E. Porter & M. J. Boda, Translating the New Testament: Text, Translation, Theology (Grand Rapids, MI: William B. Eerdmans Publishing Company, 2009), 121.

# %% [markdown]
# # 2 - Load Text-Fabric app and data <a class="anchor" id="second-bullet"></a>
# ##### [Back to TOC](#TOC)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Loading the New Testament TextFabric code
# Note: it is assumed Text-Fabric is installed in your environment.

from tf.fabric import Fabric
from tf.app import use

# %%
# load the app and data
N1904 = use ("tonyjurg/Nestle1904GBI:latest", hoist=globals())
# Out:
# **Locating corpus resources ...**
# Status: latest release online <b>0.2</b> versus <b>v0.1.1</b> locally
# downloading app, main data and requested additions ...
# <b title="latest release">app:</b> <span title="rv0.1.1=#af5dd4a4b6ea90e435d1caee5b8a8648e48a62b9">~/text-fabric-data/github/tonyjurg/Nestle1904GBI/app</span>
# The requested data is not available offline
# 	~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3 not found
# Status: latest release online <b>0.2</b> versus <b>None</b> locally
# downloading app, main data and requested additions ...
# <b title="latest release">data:</b> <span title="unknown release or commit">~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.4.10</a>, <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/app" title="tonyjurg/Nestle1904GBI app">tonyjurg/Nestle1904GBI/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/home.md" title="provenance of Nestle 1904 (GBI Nodes)">tonyjurg - Nestle1904GBI 0.3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/home.md" title="tonyjurg - Nestle1904GBI feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>27</td>
#     <td>5102.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>260</td>
#     <td>529.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>5720</td>
#     <td>24.09</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>7944</td>
#     <td>17.34</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>16124</td>
#     <td>8.54</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>73547</td>
#     <td>1.87</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>137779</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>Nestle 1904 (GBI Nodes)</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/book.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Book name (fully spelled out)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/booknum.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/booknum.tf">booknum</a>
# </div>
# <div class="fmono">int</div>
#
# <span> NT book number (Matthew=1, Mark=2, ..., Revelation=27)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/bookshort.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/bookshort.tf">bookshort</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Book name (abbreviated)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/case.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/case.tf">case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Gramatical case (Nominative, Genitive, Dative, Accusative, Vocative)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/chapter.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> Chapter number inside book</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/clause.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/clause.tf">clause</a>
# </div>
# <div class="fmono">int</div>
#
# <span> Clause number (counted per chapter)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/clauserule.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/clauserule.tf">clauserule</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Clause rule</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/clausetype.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/clausetype.tf">clausetype</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/degree.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/degree.tf">degree</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Degree (e.g. Comparitative, Superlative)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/formaltag.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/formaltag.tf">formaltag</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Formal tag (Sandborg-Petersen morphology)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/functionaltag.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/functionaltag.tf">functionaltag</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Functional tag (Sandborg-Petersen morphology)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/gloss_EN.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/gloss_EN.tf">gloss_EN</a>
# </div>
# <div class="fmono">str</div>
#
# <span> English gloss</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/gn.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/gn.tf">gn</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Gramatical gender (Masculine, Feminine, Neuter)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/lemma.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/lemma.tf">lemma</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Lexeme (lemma)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/lex_dom.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/lex_dom.tf">lex_dom</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Lexical domain according to Semantic Dictionary of Biblical Greek, SDBG (not present everywhere?)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/ln.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/ln.tf">ln</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Lauw-Nida lexical classification (not present everywhere)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/monad.md" title="~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3/monad.tf">monad</a>
# </div>
# <div class="fmono">int</div>
#
# <span> Sequence number of the smallest meaningful unit of text (single word)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/tonyjurg/Nestle1904GBI/blob/master/docs/features/mood.md" title="~
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF</a> directly usable</div><hr>

# %% [markdown]
# # 3 - Performing the queries <a class="anchor" id="third-bullet"></a>

# %% [markdown]
# ## 3.1 - Table with differences between formal and functional tag <a class="anchor" id="bullet3_1"></a>
# ##### [Back to TOC](#TOC)
#
# The following code will determine the first few Greek words where form and function are considered to be different. The first example will obtain the results in the form of a table. The output is limited to the first 10 occurences.

# %%
max=10
count=0
for node in F.otype.s('word'):
    functionaltag=F.functionaltag.v(node)
    formaltag=F.formaltag.v(node)
    if formaltag != functionaltag:
        count+=1
        book=F.book_long.v(node)
        chapter=F.chapter.v(node)
        verse=F.verse.v(node)
        word=F.word.v(node)
        gloss=F.gloss_EN.v(node)
        print (count,' - ',book,chapter,':',verse,'=\t',word,'\tformaltag:',formaltag,'\tfunctionaltag:',functionaltag, '\tgloss:', gloss)
    if count==max: break
# Out:
# 1  -  Matthew 1 : 16 =	 λεγόμενος 	formaltag: V-PEP-NSM 	functionaltag: V-PPP-NSM 	gloss: being called
# 2  -  Matthew 1 : 22 =	 ῥηθὲν 	formaltag: V-AEP-NSN 	functionaltag: V-APP-NSN 	gloss: having been spoken
# 3  -  Matthew 1 : 23 =	 μεθερμηνευόμενον 	formaltag: V-PEP-NSN 	functionaltag: V-PPP-NSN 	gloss: being translated
# 4  -  Matthew 2 : 4 =	 γεννᾶται. 	formaltag: V-PES-3S 	functionaltag: V-PPS-3S 	gloss: was to be born
# 5  -  Matthew 2 : 5 =	 γέγραπται 	formaltag: V-REI-3S 	functionaltag: V-RPI-3S 	gloss: has it been written
# 6  -  Matthew 2 : 15 =	 ῥηθὲν 	formaltag: V-AEP-NSN 	functionaltag: V-APP-NSN 	gloss: having been spoken
# 7  -  Matthew 2 : 17 =	 ῥηθὲν 	formaltag: V-AEP-NSN 	functionaltag: V-APP-NSN 	gloss: having been spoken
# 8  -  Matthew 2 : 20 =	 τεθνήκασιν 	formaltag: V-REI-3P 	functionaltag: V-RAI-3P 	gloss: they have died
# 9  -  Matthew 2 : 23 =	 λεγομένην 	formaltag: V-PEP-ASF 	functionaltag: V-PPP-ASF 	gloss: being called
# 10  -  Matthew 2 : 23 =	 ῥηθὲν 	formaltag: V-AEP-NSN 	functionaltag: V-APP-NSN 	gloss: having been spoken

# %% [markdown]
# # 3.2 Frequency of changes between form and function <a class="anchor" id="bullet3_2"></a>
# ##### [Back to TOC](#TOC)

# %%
# Library to format table
from tabulate import tabulate

ResultDict = {}
for node in F.otype.s('word'):
    FunctionalTag=F.functionaltag.v(node)
    FormalTag=F.formaltag.v(node)
    if FormalTag != FunctionalTag:
        Move=FormalTag+" -> "+FunctionalTag
        # Check if this Move already exists in ResultDict
        if Move in ResultDict:
            # If it exists, add the count to the existing value
            ResultDict[Move]+=1
        else:
            # If it doesn't exist, initialize the count as the value
            ResultDict[Move]=1
            
# Convert the dictionary into a list of key-value pairs and sort it according to frequency
UnsortedTableData = [[key, value] for key, value in ResultDict.items()]
TableData= sorted(UnsortedTableData, key=lambda row: row[1], reverse=True)

# Produce the table
headers = ["Form -> function","frequency"]
print(tabulate(TableData, headers=headers, tablefmt='fancy_grid'))
# Out:
# ╒════════════════════════════════╤═════════════╕
# │ Form -> function               │   frequency │
# ╞════════════════════════════════╪═════════════╡
# │ V-REI-3S -> V-RPI-3S           │         172 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEI-3S -> V-PPI-3S           │         166 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEN -> V-PPN                 │          98 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-NPM -> V-RPP-NPM         │          74 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-NPM -> V-PPP-NPM         │          71 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-NSM -> V-PPP-NSM         │          67 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-NSM -> V-RPP-NSM         │          62 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-ASM -> V-RPP-ASM         │          47 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEI-3P -> V-PPI-3P           │          45 │
# ├────────────────────────────────┼─────────────┤
# │ V-IEI-3P -> V-IPI-3P           │          42 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-NPM -> V-PMP-NPM         │          36 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-NSN -> V-RPP-NSN         │          36 │
# ├────────────────────────────────┼─────────────┤
# │ V-IEI-3S -> V-IPI-3S           │          34 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-ASM -> V-PPP-ASM         │          31 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEN -> V-PMN                 │          31 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-NSN -> V-PPP-NSN         │          30 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-NSM -> V-PMP-NSM         │          30 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-ASF -> V-RPP-ASF         │          29 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-ASN -> V-RPP-ASN         │          28 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-NSF -> V-RPP-NSF         │          26 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-NSF -> V-PPP-NSF         │          26 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEM-2P -> V-PPM-2P           │          25 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEI-3S -> V-PMI-3S           │          25 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-APM -> V-RPP-APM         │          24 │
# ├────────────────────────────────┼─────────────┤
# │ V-AES-3S -> V-APS-3S           │          22 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEI-1S -> V-PPI-1S           │          22 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-APN -> V-RPP-APN         │          21 │
# ├────────────────────────────────┼─────────────┤
# │ V-IEI-3P -> V-IMI-3P           │          20 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEI-3S -> V-API-3S           │          20 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-GPM -> V-RPP-GPM         │          20 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEN -> V-APN                 │          20 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEI-1S -> V-PMI-1S           │          19 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEI-2P -> V-PPI-2P           │          18 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEP-NPM -> V-APP-NPM         │          18 │
# ├────────────────────────────────┼─────────────┤
# │ V-REI-1S -> V-RPI-1S           │          18 │
# ├────────────────────────────────┼─────────────┤
# │ V-IEI-1S -> V-IMI-1S           │          16 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-APM -> V-PPP-APM         │          15 │
# ├────────────────────────────────┼─────────────┤
# │ V-FEI-3S -> V-FPI-3S           │          15 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-ASN -> V-PPP-ASN         │          15 │
# ├────────────────────────────────┼─────────────┤
# │ V-IEI-3S -> V-IMI-3S           │          15 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEI-1P -> V-PPI-1P           │          15 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-DPM -> V-RPP-DPM         │          14 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEM-2P -> V-PMM-2P           │          13 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEP-NSN -> V-APP-NSN         │          12 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-ASF -> V-PPP-ASF         │          11 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEP-NSM -> V-APP-NSM         │          11 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEI-3P -> V-API-3P           │          11 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-NPN -> V-PPP-NPN         │          11 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEM-3S -> V-PPM-3S           │          11 │
# ├────────────────────────────────┼─────────────┤
# │ V-PES-3S -> V-PPS-3S           │          10 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-GPM -> V-PPP-GPM         │          10 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-NPN -> V-RPP-NPN         │          10 │
# ├────────────────────────────────┼─────────────┤
# │ V-FEI-3P -> V-FPI-3P           │          10 │
# ├────────────────────────────────┼─────────────┤
# │ V-REN -> V-RPN                 │          10 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEI-1P -> V-PMI-1P           │           9 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEI-3P -> V-PMI-3P           │           9 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-DSF -> V-PPP-DSF         │           9 │
# ├────────────────────────────────┼─────────────┤
# │ V-REI-3P -> V-RPI-3P           │           9 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-APN -> V-PPP-APN         │           9 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-GSF -> V-PPP-GSF         │           9 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-APM -> V-PMP-APM         │           9 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEI-2P -> V-PMI-2P           │           8 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-DPM -> V-PPP-DPM         │           8 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REP-ASN -> V-2RAP-ASN       │           7 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-DPN -> V-PPP-DPN         │           7 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEM-2S -> V-PMM-2S           │           7 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEP-ASF -> V-APP-ASF         │           7 │
# ├────────────────────────────────┼─────────────┤
# │ V-FDI-3P -> V-FNI-3P           │           6 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEM-2S -> V-PPM-2S           │           6 │
# ├────────────────────────────────┼─────────────┤
# │ V-AES-1P -> V-APS-1P           │           6 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-GPN -> V-PPP-GPN         │           6 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REP-NSM -> V-2RAP-NSM       │           6 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-NPF -> V-PPP-NPF         │           6 │
# ├────────────────────────────────┼─────────────┤
# │ V-LEI-3S -> V-LPI-3S           │           5 │
# ├────────────────────────────────┼─────────────┤
# │ V-IEI-1P -> V-IMI-1P           │           5 │
# ├────────────────────────────────┼─────────────┤
# │ V-FEI-1S -> V-FPI-1S           │           5 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-GSM -> V-RPP-GSM         │           5 │
# ├────────────────────────────────┼─────────────┤
# │ V-LEI-3S-ATT -> V-LAI-3S-ATT   │           5 │
# ├────────────────────────────────┼─────────────┤
# │ V-REI-3S -> V-RAI-3S           │           5 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REN -> V-2RAN               │           5 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-GPM -> V-PMP-GPM         │           5 │
# ├────────────────────────────────┼─────────────┤
# │ V-REN -> V-RAN                 │           5 │
# ├────────────────────────────────┼─────────────┤
# │ V-IEI-1P -> V-IPI-1P           │           5 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-GSN -> V-RPP-GSN         │           5 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-NPF -> V-RPP-NPF         │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-DSM -> V-RPP-DSM         │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-DPN -> V-RPP-DPN         │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-GSM -> V-PPP-GSM         │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REI-3S -> V-2RAI-3S         │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-GPN -> V-RPP-GPN         │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-DSF -> V-RPP-DSF         │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REI-1S -> V-2RAI-1S         │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-GSN -> V-PPP-GSN         │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-DSM -> V-PPP-DSM         │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-AES-2P -> V-APS-2P           │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-APF -> V-RPP-APF         │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-PES-2P -> V-PPS-2P           │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEM-3P -> V-PPM-3P           │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REP-NPM -> V-2RAP-NPM       │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-ADI-3S -> V-ANI-3S           │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-GSF -> V-RPP-GSF         │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-REI-1P -> V-RPI-1P           │           4 │
# ├────────────────────────────────┼─────────────┤
# │ V-AES-2S -> V-APS-2S           │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-FEI-2P -> V-FPI-2P           │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-APF -> V-PPP-APF         │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-ASM -> V-RAP-ASM         │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-ASM -> V-PMP-ASM         │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-2AEI-3P -> V-2API-3P         │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEI-2S -> V-PPI-2S           │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-REI-2S -> V-RPI-2S           │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-AES-1S -> V-APS-1S           │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REP-APM -> V-2RAP-APM       │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-GSM -> V-PMP-GSM         │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-NPM -> V-RAP-NPM         │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-ASF -> V-PMP-ASF         │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-REI-2P -> V-RPI-2P           │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-AES-3P -> V-APS-3P           │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-2AEP-NPM -> V-2APP-NPM       │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEP-GSF -> V-APP-GSF         │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-2AES-3S -> V-2APS-3S         │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-2AEM-2P -> V-2APM-2P         │           3 │
# ├────────────────────────────────┼─────────────┤
# │ V-FDI-3S -> V-FNI-3S           │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEP-GSN -> V-APP-GSN         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-LEI-2P -> V-LAI-2P           │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEP-DSF -> V-APP-DSF         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-ASM -> V-RMP-ASM         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEP-ASN -> V-APP-ASN         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-LEI-3P -> V-LAI-3P           │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-ASN-ATT -> V-RPP-ASN-ATT │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEP-GSM -> V-APP-GSM         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-NSM -> V-RAP-NSM         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-GPF -> V-RPP-GPF         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-NSN-ATT -> V-RPP-NSN-ATT │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEM-2S -> V-APM-2S           │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-ASN -> V-PMP-ASN         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-DPM -> V-PMP-DPM         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEM-3S -> V-PMM-3S           │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEM-2P -> V-APM-2P           │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-PES-1S -> V-PMS-1S           │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-DSN -> V-PPP-DSN         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-PES-3P -> V-PPS-3P           │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-DSN -> V-RPP-DSN         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEI-1S -> V-API-1S           │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-PES-1S -> V-PPS-1S           │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-NSF -> V-PMP-NSF         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEP-APM -> V-APP-APM         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-PNP-NPM -> V-POP-NPM         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-PES-1P -> V-PMS-1P           │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-NPM -> V-RMP-NPM         │           2 │
# ├────────────────────────────────┼─────────────┤
# │ V-REI-3P -> V-RAI-3P           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REP-ASN -> V-2RPP-ASN       │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-GSM-ATT -> V-RAP-GSM-ATT │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-NSM -> V-RMP-NSM         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REP-ASM -> V-2RPP-ASM       │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-REM-2S -> V-RPM-2S           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REP-NSN -> V-2RAP-NSN       │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEP-NSF -> V-APP-NSF         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEP-NSM -> V-AOP-NSM         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-ADI-3P -> V-ANI-3P           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEI-2S -> V-API-2S           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEP-ASM -> V-APP-ASM         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEP-NSF -> V-AOP-NSF         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-2LEI-3S -> V-2LAI-3S         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-PES-3S -> V-PMS-3S           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REP-ASM -> V-2RAP-ASM       │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-INI-3P -> V-IDI-3P           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-DPM -> V-RAP-DPM         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-LEI-3P -> V-LMI-3P           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-LEI-3P-ATT -> V-LAI-3P-ATT   │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-ADP-NSM -> V-ANP-NSM         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REP-DSN -> V-2RAP-DSN       │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-DSM -> V-PMP-DSM         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-NPF -> V-PMP-NPF         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-ADI-3P -> V-API-3P           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-REM-2P -> V-RPM-2P           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-LEI-3S -> V-LAI-3S           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-VSM -> V-RPP-VSM         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-REI-2S -> V-RMI-2S           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-REP-GSM -> V-RAP-GSM         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-LNI-3S -> V-LDI-3S           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REI-2S -> V-2RAI-2S         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-IEI-1S -> V-IPI-1S           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-ADS-1S -> V-APS-1S           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-IEI-2P -> V-IPI-2P           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-FEI-1P -> V-FPI-1P           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-GSF -> V-PMP-GSF         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-REI-3S -> V-RMI-3S           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-AEI-1P -> V-API-1P           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-NSN -> V-PMP-NSN         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-ADS-1P -> V-APS-1P           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REI-1P -> V-2RAI-1P         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-PES-2S -> V-PMS-2S           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-RNI-3S -> V-RDI-3S           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-2REP-NSF -> V-2RAP-NSF       │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-2AES-1P -> V-2APS-1P         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-FEP-GPN -> V-FPP-GPN         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-PES-1P -> V-PPS-1P           │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-GPF -> V-PMP-GPF         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-2AEM-3S -> V-2APM-3S         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-PEP-GSN -> V-PMP-GSN         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-ADP-NSN -> V-ANP-NSN         │           1 │
# ├────────────────────────────────┼─────────────┤
# │ V-PNP-NPM -> V-PDP-NPM         │           1 │
# ╘════════════════════════════════╧═════════════╛

# %% [markdown]
# ## 3.3 - Diagram with differences between formal and functional tag <a class="anchor" id="bullet3_3"></a>
# ##### [Back to TOC](#TOC)
#
# The same results can also be presented in a tree like format. In this case a feature compare is being performed. The output is limited to the first 10 occurences.

# %%
Search0 = '''
book
 chapter
   verse
      a:word
a .formaltag#functionaltag. a
      
'''
Search0 = N1904.search(Search0)
N1904.show(Search0, start=1, end=10, condensed=True, multiFeatures=False)
# Out:
#   0.20s 2144 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://bibleol.3bmoodle.dk/text/show_text/nestle1904/Matthew/1/16" sec="Matthew 1:16">Matthew 1:16</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span> <span class="">#<span title="clause">40</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">159</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>CONJ</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>CONJ</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">160</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰακὼβ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-PRI</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-PRI</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">161</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐγέννησεν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-AAI-3S</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-AAI-3S</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">162</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τὸν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-ASM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-ASM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰωσὴφ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-PRI</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-PRI</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τὸν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-ASM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-ASM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἄνδρα</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-ASM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-ASM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Μαρίας,</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-GSF</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-GSF</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span> <span class="">#<span title="clause">41</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">163</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐξ</span></div><div class="features"><spa ...
# <p><b>verse</b> <i>2</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://bibleol.3bmoodle.dk/text/show_text/nestle1904/Matthew/1/22" sec="Matthew 1:22">Matthew 1:22</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">clause </span> <span class="">#<span title="clause">54</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">230</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>CONJ</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>CONJ</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">231</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Τοῦτο</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>D-NSN</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>D-NSN</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὅλον</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>A-NSN</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>A-NSN</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">232</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">γέγονεν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-2RAI-3S</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-2RAI-3S</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἵνα</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>CONJ</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>CONJ</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">πληρωθῇ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-APS-3S</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-APS-3S</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">233</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τὸ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-NSN</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-NSN</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">234</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">ῥηθὲν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-AEP-NSN</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-APP-NSN</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">235</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὑπὸ</span></div><div cl ...
# <p><b>verse</b> <i>3</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://bibleol.3bmoodle.dk/text/show_text/nestle1904/Matthew/1/23" sec="Matthew 1:23">Matthew 1:23</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">clause </span> <span class="">#<span title="clause">54</span></span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">236</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰδοὺ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-2AMM-2S</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-2AMM-2S</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">237</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἡ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-NSF</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-NSF</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">παρθένος</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-NSF</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-NSF</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">238</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>PREP</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>PREP</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">γαστρὶ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-DSF</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-DSF</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">239</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἕξει</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-FAI-3S</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-FAI-3S</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>CONJ</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>CONJ</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τέξεται</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-FDI-3S</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-FDI-3S</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">240</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">υἱόν,</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-ASM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-ASM</span></div></div></div ...
# <p><b>verse</b> <i>4</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://bibleol.3bmoodle.dk/text/show_text/nestle1904/Matthew/2/4" sec="Matthew 2:4">Matthew 2:4</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span> <span class="">#<span title="clause">64</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">295</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>CONJ</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>CONJ</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">296</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">συναγαγὼν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-2AAP-NSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-2AAP-NSM</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">297</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">πάντας</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>A-APM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>A-APM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τοὺς</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-APM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-APM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀρχιερεῖς</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-APM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-APM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>CONJ</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>CONJ</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">γραμματεῖς</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-APM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-APM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τοῦ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-GSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-GSM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">λαοῦ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-GSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-GSM</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">298</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐπυνθάνετο</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-INI-3S</span><s ...
# <p><b>verse</b> <i>5</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://bibleol.3bmoodle.dk/text/show_text/nestle1904/Matthew/2/5" sec="Matthew 2:5">Matthew 2:5</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">clause </span> <span class="">#<span title="clause">65</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">302</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>CONJ</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>CONJ</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">303</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">οἱ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-NPM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-NPM</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">304</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">εἶπαν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-2AAI-3P</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-2AAI-3P</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">305</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">αὐτῷ·</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>P-DSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>P-DSM</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">306</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἐν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>PREP</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>PREP</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Βηθλέεμ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-PRI</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-PRI</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τῆς</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-GSF</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-GSF</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰουδαίας·</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-GSF</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-GSF</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">γὰρ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>CONJ</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>CONJ</span></div></div><div class="contnr c0 trm   ...
# <p><b>verse</b> <i>6</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://bibleol.3bmoodle.dk/text/show_text/nestle1904/Matthew/2/15" sec="Matthew 2:15">Matthew 2:15</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span> <span class="">#<span title="clause">87</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">416</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>CONJ</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>CONJ</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">417</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἦν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-IAI-3S</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-IAI-3S</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">418</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐκεῖ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>ADV</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>ADV</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">419</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἕως</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>ADV</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>ADV</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τῆς</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-GSF</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-GSF</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τελευτῆς</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-GSF</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-GSF</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἠρῴδου·</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-GSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-GSM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἵνα</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>CONJ</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>CONJ</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">420</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">πληρωθῇ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-APS-3S</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-APS-3S</span></div></div></div></div><div class="con ...
# <p><b>verse</b> <i>7</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://bibleol.3bmoodle.dk/text/show_text/nestle1904/Matthew/2/17" sec="Matthew 2:17">Matthew 2:17</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">clause </span> <span class="">#<span title="clause">91</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">441</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τότε</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>ADV</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>ADV</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">442</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐπληρώθη</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-API-3S</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-API-3S</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">443</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τὸ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-NSN</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-NSN</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">444</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">ῥηθὲν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-AEP-NSN</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-APP-NSN</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">445</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">διὰ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>PREP</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>PREP</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰερεμίου</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-GSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-GSM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τοῦ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-GSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-GSM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">προφήτου</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-GSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-GSM</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">446</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">λέγοντος</span></div><div c ...
# <p><b>verse</b> <i>8</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://bibleol.3bmoodle.dk/text/show_text/nestle1904/Matthew/2/20" sec="Matthew 2:20">Matthew 2:20</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">clause </span> <span class="">#<span title="clause">95</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">464</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">λέγων</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-PAP-NSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-PAP-NSM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἐγερθεὶς</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-APP-NSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-APP-NSM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">παράλαβε</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-2AAM-2S</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-2AAM-2S</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">465</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τὸ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-ASN</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-ASN</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">παιδίον</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-ASN</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-ASN</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>CONJ</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>CONJ</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τὴν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-ASF</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-ASF</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">μητέρα</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-ASF</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-ASF</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">αὐτοῦ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>P-GSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>P-GSM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>CONJ</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>CONJ</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">466</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">πορεύου</span ...
# <p><b>verse</b> <i>9</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://bibleol.3bmoodle.dk/text/show_text/nestle1904/Matthew/2/23" sec="Matthew 2:23">Matthew 2:23</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span> <span class="">#<span title="clause">98</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">489</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>CONJ</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>CONJ</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">490</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐλθὼν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-2AAP-NSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-2AAP-NSM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">κατῴκησεν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-AAI-3S</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-AAI-3S</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">491</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">εἰς</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>PREP</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>PREP</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">πόλιν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-ASF</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-ASF</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">492</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">λεγομένην</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-PEP-ASF</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-PPP-ASF</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">493</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ναζαρέτ·</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-PRI</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-PRI</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὅπως</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>ADV</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>ADV</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">494</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">πληρωθῇ</span></d ...
# <p><b>verse</b> <i>10</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://bibleol.3bmoodle.dk/text/show_text/nestle1904/Matthew/3/3" sec="Matthew 3:3">Matthew 3:3</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span> <span class="">#<span title="clause">101</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">508</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">γάρ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>CONJ</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>CONJ</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">οὗτος</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>D-NSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>D-NSM</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">509</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐστιν</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-PAI-3S</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-PAI-3S</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">510</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-NSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-NSM</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">511</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">ῥηθεὶς</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>V-AEP-NSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>V-APP-NSM</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="phrase">512</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">διὰ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>PREP</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>PREP</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἠσαΐου</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-GSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-GSM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τοῦ</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>T-GSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>T-GSM</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">προφήτου</span></div><div class="features"><span class="formaltag xft" ><span class="f">formaltag=</span>N-GSM</span><span class="functionaltag xft" ><span class="f">functionaltag=</span>N-GSM</span></div></div></div></div><di ...
