# %% [markdown]
# # Print a specific verse (Nestle1904GBI)

# %% [markdown]
# ## Table of content <a class="anchor" id="TOC">
# * [1 - Introduction](#first-bullet)
# * [2 - Load Text-Fabric app and data](#second-bullet)
# * [3 - Performing the queries](#third-bullet)
#     * [3.1 - Show all object phrases in clauses](#bullet3_1)

# %% [markdown]
# # 1 - Introduction <a class="anchor" id="first-bullet"></a>
#
# TBD

# %% [markdown]
# # 2 - Load Text-Fabric app and data <a class="anchor" id="second-bullet"></a>
# ##### [Back to TOC](#TOC)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Loading the New Testament TextFabric code
# Note: it is assumed Text-Fabric is installed in your environment.

from tf.fabric import Fabric
from tf.app import use

# %%
# load the app and data
N1904 = use ("tonyjurg/Nestle1904GBI:latest", hoist=globals())
# Out:
# **Locating corpus resources ...**
# Status: latest release online <b>0.2</b> versus <b>v0.1.1</b> locally
# downloading app, main data and requested additions ...
# <b title="latest release">app:</b> <span title="rv0.1.1=#af5dd4a4b6ea90e435d1caee5b8a8648e48a62b9">~/text-fabric-data/github/tonyjurg/Nestle1904GBI/app</span>
# The requested data is not available offline
# 	~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3 not found
# Status: latest release online <b>0.2</b> versus <b>None</b> locally
# downloading app, main data and requested additions ...
# <b title="latest release">data:</b> <span title="unknown release or commit">~/text-fabric-data/github/tonyjurg/Nestle1904GBI/tf/0.3</span>
# ...

# %% [markdown]
# # 3 - Performing the queries <a class="anchor" id="third-bullet"></a>

# %% [markdown]
# ### 3.1 - Show all object phrases in clauses <a class="anchor" id="bullet3_1"></a>
# ##### [back to TOC](#TOC)
#
# The following example will query (and indicate) phrases with function 'O' (=Object). This is done by selecting  versed containing the value 'O' for feature 'phrasefunction' belonging to node type 'phrase'. See also the [feature description of 'phrasefunction'](https://tonyjurg.github.io/Nestle1904GBI/features/phrasefunction.html). It starts with examining at the first verse of Matthews. The first Object phrase in Matthew is found in verse 2. The display is limited to the first two verses found containing an Object phrase.

# %%
Search0 = '''
book book=Matthew
  chapter chapter=1
      verse verse=20
'''
Search0 = N1904.search(Search0)
N1904.show(Search0, start=1, end=2, condensed=True, extraFeatures={'sp', 'clauserule', 'phrasefunction_long'}, multiFeatures=True)
# Out:
#   0.01s 1 result
# <p><b>verse</b> <i>1</i>
# ...

# %% [markdown]
# # available output formats
#
# To check the available formats to display the text:

# %%
N1904.showFormats()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 A.showFormats()
#
# NameError: name 'A' is not defined
